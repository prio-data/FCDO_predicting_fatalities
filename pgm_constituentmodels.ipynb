# %% [markdown]
# # ViEWS 3 constituent models
#
# ## Fatalities project, pgm level
#
#
# This notebook trains a set of regression models for use in a predicting fatalities ensemble
#
#
# The notebook does the following:
# 1. Retrieves data through querysets and stores in DataSets, a list of dictionaries
# 2. Specifies the metadata of a number of models, stores in ModelList, a list of dictionaries
# 3. Trains the models in ModelList, stores the trained objects in model storage and prediction storage

# %% [markdown]
# ## Importing models

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Basics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
# sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.ensemble import AdaBoostRegressor
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression

from xgboost import XGBRegressor
from xgboost import XGBClassifier
from xgboost import XGBRFRegressor, XGBRFClassifier

from lightgbm import LGBMClassifier, LGBMRegressor

# Views 3
from viewser.operations import fetch
import views_runs
from views_partitioning import data_partitioner, legacy
from stepshift import views
import views_dataviz
from views_runs import storage
from views_runs.storage import store, retrieve, fetch_metadata

from views_forecasts.extensions import *

# Other packages
import pickle as pkl

# Packages from Predicting Fatalies repository

from HurdleRegression import * # Built on script from Geoff Hurdock: https://geoffruddock.com/building-a-hurdle-regression-estimator-in-scikit-learn/
from Ensembling import CalibratePredictions, RetrieveStoredPredictions, mean_sd_calibrated, gam_calibrated
import FetchData
from FetchData import FetchData_pgm, RetrieveFromList, data_integrity_check, index_check
from HurdleRegression import *

# %% [markdown]
# ## Common parameters

# %%
# Common parameters:
dev_id = 'Fatalities001'
run_id = 'Fatalities001'

# Generating a new run if necessary

#try:
#    ViewsMetadata().new_run(name=run_id,description='pgm_level_fatalities',min_month=1,max_month=999)
#except KeyError:
#    if 'devel' not in run_id:
#        warnings.warn('You are overwriting a production system')

depvar="ln_ged_sb_dep"

RerunQuerysets = True
        
FutureStart = 506
steps = [*range(1, 36+1, 1)] # Which steps to train and predict for
fi_steps = [1,3,6,12,36] # Which steps to present feature importances for
#steps = [1,3,6,12,36]
#fi_steps = [1,3,6,12,36]

# Specifying partitions
calib_partitioner_dict = {"train":(121,396),"predict":(397,444)}
test_partitioner_dict = {"train":(121,444),"predict":(445,492)}
future_partitioner_dict = {"train":(121,492),"predict":(493,504)}
calib_partitioner =  views_runs.DataPartitioner({"calib":calib_partitioner_dict})
test_partitioner =  views_runs.DataPartitioner({"test":test_partitioner_dict})
future_partitioner =  views_runs.DataPartitioner({"future":future_partitioner_dict})

Mydropbox = '/Users/jim/Dropbox (ViEWS)/ViEWS'

# %% [markdown]
# ## Retrieve data

# %%
if RerunQuerysets:
    import pgm_querysets
# Out:
#  .
# A dataset with 8 columns, with data between t 1 and 852. (13110 units)
#  .
# A dataset with 19 columns, with data between t 1 and 852. (13110 units)
#  .
# A dataset with 29 columns, with data between t 1 and 852. (13110 units)
#  .
# A dataset with 24 columns, with data between t 1 and 852. (13110 units)
#  .
# A dataset with 23 columns, with data between t 1 and 852. (13110 units)
#  .
# A dataset with 30 columns, with data between t 1 and 852. (13110 units)
#  .
# A dataset with 8 columns, with data between t 1 and 852. (13110 units)
#  .
# A dataset with 11 columns, with data between t 1 and 852. (13110 units)

# %%
Datasets = FetchData_pgm(dev_id)
# Out:
# Fetching data using querysets; returns as list of dictionaries containing datasets
#  .    baseline: A dataset with 8 columns, with data between t = 1 and 852; 13110 units.
#  .    conflictlong: A dataset with 19 columns, with data between t = 1 and 852; 13110 units.
#  .    escwa_drought: A dataset with 29 columns, with data between t = 1 and 852; 13110 units.
#  .    natsoc: A dataset with 24 columns, with data between t = 1 and 852; 13110 units.
#  .    broad: A dataset with 23 columns, with data between t = 1 and 852; 13110 units.
#  .    paola_conf_hist: A dataset with 30 columns, with data between t = 1 and 852; 13110 units.
#  .    conf_treelag: A dataset with 8 columns, with data between t = 1 and 852; 13110 units.
#  .    conf_sptime_dist: A dataset with 11 columns, with data between t = 1 and 852; 13110 units.

# %%
for ds in Datasets:

    FetchData.data_integrity_check(ds,depvar)
# Out:
# Reordering columns in model escwa_drought
# Reordering columns in model broad
# Reordering columns in model conf_treelag
# Reordering columns in model conf_sptime_dist

# %% [markdown]
# ## Define regressors

# %%
nj=12
n_estimators=200

rf_regressor=RandomForestRegressor(n_estimators=n_estimators, n_jobs=nj)

xgb_regressor=XGBRegressor(n_estimators=n_estimators,tree_method='hist',n_jobs=nj)

lgbm_regressor=LGBMRegressor(n_estimators=n_estimators)

clf_params={'n_estimators':n_estimators,'n_jobs':nj}

reg_params={'n_estimators':n_estimators,'n_jobs':nj}

clf_lgbm_params={'n_estimators':n_estimators}

reg_lgbm_params={'n_estimators':n_estimators}

hur_regressor=HurdleRegression(clf_name='XGBClassifier',reg_name='XGBRegressor',clf_params=clf_params,reg_params=reg_params)
hur_lgbm_regressor=HurdleRegression(clf_name='LGBMClassifier',reg_name='LGBMRegressor',clf_params=clf_lgbm_params,reg_params=reg_lgbm_params)

# %% [markdown]
# ## Specify models

# %%
ModelList = []

model = {
    'modelname': 'fat_jed_hh_baseline_lgbm',
    'algorithm': lgbm_regressor,
    'depvar': depvar,
    'queryset':'hh_fat_pgm_baseline',
    'data_train': 'baseline'

    
}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_conflictlong_lgbm',
    'algorithm': lgbm_regressor,
    'depvar': depvar,
    'queryset':'hh_fat_pgm_conflictlong',
    'data_train': 'conflictlong'

}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_conflictlong_hurdle_lgbm',
    'algorithm': hur_lgbm_regressor,
    'depvar': depvar,
    'queryset':'hh_fat_pgm_conflictlong',
    'data_train': 'conflictlong'

}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_drought_hurdle_lgbm',
    'algorithm': hur_lgbm_regressor,
    'depvar': depvar,
    'queryset':'fat_escwa_drought_vulnerability_pgm',
    'data_train': 'escwa_drought'

}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_drought_lgbm',
    'algorithm': lgbm_regressor,
    'depvar': depvar,
    'queryset':'fat_escwa_drought_vulnerability_pgm',
    'data_train': 'escwa_drought'
    
}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_natsoc_hurdle_lgbm',
    'algorithm': hur_lgbm_regressor,
    'depvar': depvar,
    'queryset':'hh_fat_pgm_natsoc',
    'data_train': 'natsoc'
    
}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_natsoc_lgbm',
    'algorithm': lgbm_regressor,
    'depvar': depvar,
    'queryset':'hh_fat_pgm_natsoc',
    'data_train': 'natsoc'

}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_broad_hurdle_lgbm',
    'algorithm': hur_lgbm_regressor,
    'depvar': depvar,
    'queryset':'hh_fat_pgm_broad',
    'data_train': 'broad'

}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_hh_broad_lgbm',
    'algorithm': lgbm_regressor,
    'depvar': depvar,
    'queryset':'hh_fat_pgm_broad',
    'data_train': 'broad'

}
ModelList.append(model)

model = {
    'modelname': 'fat_jed_pv_conf_hist_pgm',
    'algorithm': xgb_regressor,
    'depvar': depvar,
    'queryset': 'paola_fatalities_conflict_history',
    'data_train': 'paola_conf_hist'

}

ModelList.append(model)

model = {
    'modelname': 'fat_tree_lags_d_1_d_2_hur_36',
    'algorithm': hur_regressor,
    'depvar': depvar,
    'queryset':'jim_pgm_conflict_treelag_d_1_d_2',
    'data_train': 'conf_treelag'

}
ModelList.append(model)

model = {
    'modelname': 'fat_sptime_dist_nu1_10_001_hur_36',
    'algorithm': hur_regressor,
    'depvar': depvar,
    'queryset':'jim_pgm_conflict_target_sptime_dist_nu1_10_001',
    'data_train': 'conf_sptime_dist'

}
ModelList.append(model)

# %%
# Loop that checks whether the model exists, retrains if not, 
# and stores the predictions if they have not been stored before for this run.
# To do: set the data_preprocessing to the function in the model dictionary

level = 'pgm'
includeFuture = True

from views_runs import Storage, StepshiftedModels
from views_partitioning.data_partitioner import DataPartitioner
from viewser import Queryset, Column
from views_runs import operations
from views_runs.run_result import RunResult

i = 0
for model in ModelList:
    force_retrain = False
    modelstore = storage.Storage()
    ct = datetime.now()
    print(i, model['modelname'])
    print('Calibration partition', ct)
    model['Algorithm_text'] = str(model['algorithm'])
    model['RunResult_calib'] = RunResult.retrain_or_retrieve(
            retrain            = force_retrain,
            store              = modelstore,
            partitioner        = DataPartitioner({"calib":calib_partitioner_dict}),
            stepshifted_models = StepshiftedModels(model['algorithm'], steps, model['depvar']),
            dataset            = RetrieveFromList(Datasets,model['data_train']),
            queryset_name      = model['queryset'],
            partition_name     = "calib",
            timespan_name      = "train",
            storage_name       = model['modelname'] + '_calib',
            author_name        = "JED",
    )

    model['predstore_calib'] = level +  '_' + model['modelname'] + '_calib'
    ct = datetime.now()
    print('Trying to retrieve predictions', ct)
    try:
        predictions_calib = pd.DataFrame.forecasts.read_store(run=run_id, name=model['predstore_calib'])
    except KeyError:
        print(model['predstore_calib'], ', run',  run_id, 'does not exist, predicting')
        predictions_calib = model['RunResult_calib'].run.predict("calib","predict", model['RunResult_calib'].data)
        predictions_calib.forecasts.set_run(run_id)
        predictions_calib.forecasts.to_store(name=model['predstore_calib'])

    ct = datetime.now()
    print('Test partition', ct)
    modelstore = storage.Storage()
    model['RunResult_test'] = RunResult.retrain_or_retrieve(
            retrain            = force_retrain,
            store              = modelstore,
            partitioner        = DataPartitioner({"test":test_partitioner_dict}),
            stepshifted_models = StepshiftedModels(model['algorithm'], steps, model['depvar']),
            dataset            = RetrieveFromList(Datasets,model['data_train']),
            queryset_name      = model['queryset'],
            partition_name     = "test",
            timespan_name      = "train",
            storage_name       = model['modelname'] + '_test',
            author_name        = "JED",
    )
    ct = datetime.now()
    print('Trying to retrieve predictions', ct)
    model['predstore_test'] = level +  '_' + model['modelname'] + '_test'
    try:
        predictions_test = pd.DataFrame.forecasts.read_store(run=run_id, name=model['predstore_test'])
    except KeyError:
        print(model['predstore_test'], ', run', run_id, 'does not exist, predicting')
        predictions_test = model['RunResult_test'].run.predict("test","predict",model['RunResult_test'].data)
        predictions_test.forecasts.set_run(run_id)
        predictions_test.forecasts.to_store(name=model['predstore_test'])
    # Predictions for true future
    if includeFuture:
        ct = datetime.now()
        print('Future', ct)
        modelstore = storage.Storage()
        model['RunResult_future'] = RunResult.retrain_or_retrieve(
                retrain            = force_retrain,
                store              = modelstore,
                partitioner        = DataPartitioner({"test":future_partitioner_dict}),
                stepshifted_models = StepshiftedModels(model['algorithm'], steps, model['depvar']),
                dataset            = RetrieveFromList(Datasets,model['data_train']),
                queryset_name      = model['queryset'],
                partition_name     = "test",
                timespan_name      = "train",
                storage_name       = model['modelname'] + '_future',
                author_name        = "JED",
        )
        ct = datetime.now()
        print('Trying to retrieve predictions', ct)
        model['predstore_future'] = level +  '_' + model['modelname'] + '_f' + str(FutureStart)
        try:
            predictions_future = pd.DataFrame.forecasts.read_store(run=run_id, name=model['predstore_future'])
        except KeyError:
            print(model['predstore_future'], ', run', run_id, 'does not exist, predicting')
            predictions_future = model['RunResult_future'].run.future_point_predict(FutureStart,model['RunResult_future'].data)
            predictions_future.forecasts.set_run(run_id)
            predictions_future.forecasts.to_store(name=model['predstore_future'])  
#    model['algorithm'] = []
    i = i + 1

print('All done')
# Out:
# 0 fat_jed_hh_baseline_lgbm
# Calibration partition 2022-05-29 15:35:11.299896
#  * == Performing a run: "fat_jed_hh_baseline_lgbm_calib" == *
# Model object named "fat_jed_hh_baseline_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_baseline_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:35:13.098795
# pr_45_pgm_fat_jed_hh_baseline_lgbm_calib.parquet
# Test partition 2022-05-29 15:35:20.130285
#  * == Performing a run: "fat_jed_hh_baseline_lgbm_test" == *
# Model object named "fat_jed_hh_baseline_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_baseline_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:35:22.110882
# pr_45_pgm_fat_jed_hh_baseline_lgbm_test.parquet
# Future 2022-05-29 15:35:28.832478
#  * == Performing a run: "fat_jed_hh_baseline_lgbm_future" == *
# Model object named "fat_jed_hh_baseline_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_baseline_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:35:30.877850
# pr_45_pgm_fat_jed_hh_baseline_lgbm_f506.parquet
# 1 fat_jed_hh_conflictlong_lgbm
# Calibration partition 2022-05-29 15:35:33.199098
#  * == Performing a run: "fat_jed_hh_conflictlong_lgbm_calib" == *
# Model object named "fat_jed_hh_conflictlong_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_conflictlong_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:35:35.122425
# pr_45_pgm_fat_jed_hh_conflictlong_lgbm_calib.parquet
# Test partition 2022-05-29 15:35:40.142967
#  * == Performing a run: "fat_jed_hh_conflictlong_lgbm_test" == *
# Model object named "fat_jed_hh_conflictlong_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_conflictlong_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:35:42.363475
# pr_45_pgm_fat_jed_hh_conflictlong_lgbm_test.parquet
# Future 2022-05-29 15:35:47.684787
#  * == Performing a run: "fat_jed_hh_conflictlong_lgbm_future" == *
# Model object named "fat_jed_hh_conflictlong_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_conflictlong_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:35:49.438349
# pr_45_pgm_fat_jed_hh_conflictlong_lgbm_f506.parquet
# 2 fat_jed_hh_conflictlong_hurdle_lgbm
# Calibration partition 2022-05-29 15:35:51.773960
#  * == Performing a run: "fat_jed_hh_conflictlong_hurdle_lgbm_calib" == *
# Model object named "fat_jed_hh_conflictlong_hurdle_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_conflictlong_hurdle_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:35:55.419149
# pr_45_pgm_fat_jed_hh_conflictlong_hurdle_lgbm_calib.parquet
# Test partition 2022-05-29 15:36:03.111949
#  * == Performing a run: "fat_jed_hh_conflictlong_hurdle_lgbm_test" == *
# Model object named "fat_jed_hh_conflictlong_hurdle_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_conflictlong_hurdle_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:36:06.994456
# pr_45_pgm_fat_jed_hh_conflictlong_hurdle_lgbm_test.parquet
# Future 2022-05-29 15:36:15.163620
#  * == Performing a run: "fat_jed_hh_conflictlong_hurdle_lgbm_future" == *
# Model object named "fat_jed_hh_conflictlong_hurdle_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_conflictlong_hurdle_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:36:19.000063
# pr_45_pgm_fat_jed_hh_conflictlong_hurdle_lgbm_f506.parquet
# 3 fat_jed_hh_drought_hurdle_lgbm
# Calibration partition 2022-05-29 15:36:21.755456
#  * == Performing a run: "fat_jed_hh_drought_hurdle_lgbm_calib" == *
# Model object named "fat_jed_hh_drought_hurdle_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_drought_hurdle_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:36:25.756706
# pr_45_pgm_fat_jed_hh_drought_hurdle_lgbm_calib.parquet
# Test partition 2022-05-29 15:36:39.449194
#  * == Performing a run: "fat_jed_hh_drought_hurdle_lgbm_test" == *
# Model object named "fat_jed_hh_drought_hurdle_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_drought_hurdle_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:36:43.406415
# pr_45_pgm_fat_jed_hh_drought_hurdle_lgbm_test.parquet
# Future 2022-05-29 15:37:03.479994
#  * == Performing a run: "fat_jed_hh_drought_hurdle_lgbm_future" == *
# Model object named "fat_jed_hh_drought_hurdle_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_drought_hurdle_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:37:07.542297
# pr_45_pgm_fat_jed_hh_drought_hurdle_lgbm_f506.parquet
# 4 fat_jed_hh_drought_lgbm
# Calibration partition 2022-05-29 15:37:10.224848
#  * == Performing a run: "fat_jed_hh_drought_lgbm_calib" == *
# Model object named "fat_jed_hh_drought_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_drought_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:37:11.993960
# pr_45_pgm_fat_jed_hh_drought_lgbm_calib.parquet
# Test partition 2022-05-29 15:37:23.391294
#  * == Performing a run: "fat_jed_hh_drought_lgbm_test" == *
# Model object named "fat_jed_hh_drought_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_drought_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:37:25.100692
# pr_45_pgm_fat_jed_hh_drought_lgbm_test.parquet
# Future 2022-05-29 15:37:34.782965
#  * == Performing a run: "fat_jed_hh_drought_lgbm_future" == *
# Model object named "fat_jed_hh_drought_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_drought_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:37:36.536893
# pr_45_pgm_fat_jed_hh_drought_lgbm_f506.parquet
# 5 fat_jed_hh_natsoc_hurdle_lgbm
# Calibration partition 2022-05-29 15:37:39.347414
#  * == Performing a run: "fat_jed_hh_natsoc_hurdle_lgbm_calib" == *
# Model object named "fat_jed_hh_natsoc_hurdle_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_natsoc_hurdle_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:37:43.100619
# pr_45_pgm_fat_jed_hh_natsoc_hurdle_lgbm_calib.parquet
# Test partition 2022-05-29 15:37:51.284993
#  * == Performing a run: "fat_jed_hh_natsoc_hurdle_lgbm_test" == *
# Model object named "fat_jed_hh_natsoc_hurdle_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_natsoc_hurdle_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:37:55.609672
# pr_45_pgm_fat_jed_hh_natsoc_hurdle_lgbm_test.parquet
# Future 2022-05-29 15:38:12.384637
#  * == Performing a run: "fat_jed_hh_natsoc_hurdle_lgbm_future" == *
# Model object named "fat_jed_hh_natsoc_hurdle_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_natsoc_hurdle_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:38:17.312199
# pr_45_pgm_fat_jed_hh_natsoc_hurdle_lgbm_f506.parquet
# 6 fat_jed_hh_natsoc_lgbm
# Calibration partition 2022-05-29 15:38:20.180013
#  * == Performing a run: "fat_jed_hh_natsoc_lgbm_calib" == *
# Model object named "fat_jed_hh_natsoc_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_natsoc_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:38:21.812330
# pr_45_pgm_fat_jed_hh_natsoc_lgbm_calib.parquet
# Test partition 2022-05-29 15:38:30.083296
#  * == Performing a run: "fat_jed_hh_natsoc_lgbm_test" == *
# Model object named "fat_jed_hh_natsoc_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_natsoc_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:38:32.125618
# pr_45_pgm_fat_jed_hh_natsoc_lgbm_test.parquet
# Future 2022-05-29 15:38:41.480550
#  * == Performing a run: "fat_jed_hh_natsoc_lgbm_future" == *
# Model object named "fat_jed_hh_natsoc_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_natsoc_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:38:43.228639
# pr_45_pgm_fat_jed_hh_natsoc_lgbm_f506.parquet
# 7 fat_jed_hh_broad_hurdle_lgbm
# Calibration partition 2022-05-29 15:38:45.734076
#  * == Performing a run: "fat_jed_hh_broad_hurdle_lgbm_calib" == *
# Model object named "fat_jed_hh_broad_hurdle_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_broad_hurdle_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:38:49.644375
# pr_45_pgm_fat_jed_hh_broad_hurdle_lgbm_calib.parquet
# Test partition 2022-05-29 15:39:16.426601
#  * == Performing a run: "fat_jed_hh_broad_hurdle_lgbm_test" == *
# Model object named "fat_jed_hh_broad_hurdle_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_broad_hurdle_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:39:20.740431
# pr_45_pgm_fat_jed_hh_broad_hurdle_lgbm_test.parquet
# Future 2022-05-29 15:39:45.587978
#  * == Performing a run: "fat_jed_hh_broad_hurdle_lgbm_future" == *
# Model object named "fat_jed_hh_broad_hurdle_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_broad_hurdle_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:39:49.730025
# pr_45_pgm_fat_jed_hh_broad_hurdle_lgbm_f506.parquet
# 8 fat_jed_hh_broad_lgbm
# Calibration partition 2022-05-29 15:39:52.387447
#  * == Performing a run: "fat_jed_hh_broad_lgbm_calib" == *
# Model object named "fat_jed_hh_broad_lgbm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_hh_broad_lgbm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:39:54.420756
# pr_45_pgm_fat_jed_hh_broad_lgbm_calib.parquet
# Test partition 2022-05-29 15:40:07.656792
#  * == Performing a run: "fat_jed_hh_broad_lgbm_test" == *
# Model object named "fat_jed_hh_broad_lgbm_test" with equivalent metadata already exists.
# Fetching "fat_jed_hh_broad_lgbm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:40:09.837051
# pr_45_pgm_fat_jed_hh_broad_lgbm_test.parquet
# Future 2022-05-29 15:40:21.692146
#  * == Performing a run: "fat_jed_hh_broad_lgbm_future" == *
# Model object named "fat_jed_hh_broad_lgbm_future" with equivalent metadata already exists.
# Fetching "fat_jed_hh_broad_lgbm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:40:23.664973
# pr_45_pgm_fat_jed_hh_broad_lgbm_f506.parquet
# 9 fat_jed_pv_conf_hist_pgm
# Calibration partition 2022-05-29 15:40:26.630070
#  * == Performing a run: "fat_jed_pv_conf_hist_pgm_calib" == *
# Model object named "fat_jed_pv_conf_hist_pgm_calib" with equivalent metadata already exists.
# Fetching "fat_jed_pv_conf_hist_pgm_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:40:29.887965
# pr_45_pgm_fat_jed_pv_conf_hist_pgm_calib.parquet
# Test partition 2022-05-29 15:40:34.855477
#  * == Performing a run: "fat_jed_pv_conf_hist_pgm_test" == *
# Model object named "fat_jed_pv_conf_hist_pgm_test" with equivalent metadata already exists.
# Fetching "fat_jed_pv_conf_hist_pgm_test" from storage
# Trying to retrieve predictions 2022-05-29 15:40:38.503104
# pr_45_pgm_fat_jed_pv_conf_hist_pgm_test.parquet
# Future 2022-05-29 15:40:42.815853
#  * == Performing a run: "fat_jed_pv_conf_hist_pgm_future" == *
# Model object named "fat_jed_pv_conf_hist_pgm_future" with equivalent metadata already exists.
# Fetching "fat_jed_pv_conf_hist_pgm_future" from storage
# Trying to retrieve predictions 2022-05-29 15:40:46.055537
# pr_45_pgm_fat_jed_pv_conf_hist_pgm_f506.parquet
# 10 fat_tree_lags_d_1_d_2_hur_36
# Calibration partition 2022-05-29 15:40:48.324079
#  * == Performing a run: "fat_tree_lags_d_1_d_2_hur_36_calib" == *
# Model object named "fat_tree_lags_d_1_d_2_hur_36_calib" with equivalent metadata already exists.
# Fetching "fat_tree_lags_d_1_d_2_hur_36_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:40:55.049374
# pr_45_pgm_fat_tree_lags_d_1_d_2_hur_36_calib.parquet
# Test partition 2022-05-29 15:41:14.183129
#  * == Performing a run: "fat_tree_lags_d_1_d_2_hur_36_test" == *
# Model object named "fat_tree_lags_d_1_d_2_hur_36_test" with equivalent metadata already exists.
# Fetching "fat_tree_lags_d_1_d_2_hur_36_test" from storage
# Trying to retrieve predictions 2022-05-29 15:41:21.192025
# pr_45_pgm_fat_tree_lags_d_1_d_2_hur_36_test.parquet
# Future 2022-05-29 15:41:45.183895
#  * == Performing a run: "fat_tree_lags_d_1_d_2_hur_36_future" == *
# Model object named "fat_tree_lags_d_1_d_2_hur_36_future" with equivalent metadata already exists.
# Fetching "fat_tree_lags_d_1_d_2_hur_36_future" from storage
# Trying to retrieve predictions 2022-05-29 15:41:51.727018
# pr_45_pgm_fat_tree_lags_d_1_d_2_hur_36_f506.parquet
# 11 fat_sptime_dist_nu1_10_001_hur_36
# Calibration partition 2022-05-29 15:41:54.979664
#  * == Performing a run: "fat_sptime_dist_nu1_10_001_hur_36_calib" == *
# Model object named "fat_sptime_dist_nu1_10_001_hur_36_calib" with equivalent metadata already exists.
# Fetching "fat_sptime_dist_nu1_10_001_hur_36_calib" from storage
# Trying to retrieve predictions 2022-05-29 15:42:01.889845
# pr_45_pgm_fat_sptime_dist_nu1_10_001_hur_36_calib.parquet
# Test partition 2022-05-29 15:42:22.509134
#  * == Performing a run: "fat_sptime_dist_nu1_10_001_hur_36_test" == *
# Model object named "fat_sptime_dist_nu1_10_001_hur_36_test" with equivalent metadata already exists.
# Fetching "fat_sptime_dist_nu1_10_001_hur_36_test" from storage
# Trying to retrieve predictions 2022-05-29 15:42:29.566387
# pr_45_pgm_fat_sptime_dist_nu1_10_001_hur_36_test.parquet
# Future 2022-05-29 15:42:51.432366
#  * == Performing a run: "fat_sptime_dist_nu1_10_001_hur_36_future" == *
# Model object named "fat_sptime_dist_nu1_10_001_hur_36_future" with equivalent metadata already exists.
# Fetching "fat_sptime_dist_nu1_10_001_hur_36_future" from storage
# Trying to retrieve predictions 2022-05-29 15:42:58.748502
# pr_45_pgm_fat_sptime_dist_nu1_10_001_hur_36_f506.parquet
# All done

# %%
ModelMetaData = pd.DataFrame(ModelList)

# %%
ModelMetaData
# Out:
#                               modelname  \
# 0              fat_jed_hh_baseline_lgbm
# 1          fat_jed_hh_conflictlong_lgbm
# 2   fat_jed_hh_conflictlong_hurdle_lgbm
# 3        fat_jed_hh_drought_hurdle_lgbm
# 4               fat_jed_hh_drought_lgbm
# 5         fat_jed_hh_natsoc_hurdle_lgbm
# 6                fat_jed_hh_natsoc_lgbm
# 7          fat_jed_hh_broad_hurdle_lgbm
# 8                 fat_jed_hh_broad_lgbm
# 9              fat_jed_pv_conf_hist_pgm
# 10         fat_tree_lags_d_1_d_2_hur_36
# 11    fat_sptime_dist_nu1_10_001_hur_36
#
#                                             algorithm         depvar  \
# 0                     LGBMRegressor(n_estimators=200)  ln_ged_sb_dep
# 1                     LGBMRegressor(n_estimators=200)  ln_ged_sb_dep
# 2   HurdleRegression(clf_name='LGBMClassifier', cl...  ln_ged_sb_dep
# 3   HurdleRegression(clf_name='LGBMClassifier', cl...  ln_ged_sb_dep
# 4                     LGBMRegressor(n_estimators=200)  ln_ged_sb_dep
# 5   HurdleRegression(clf_name='LGBMClassifier', cl...  ln_ged_sb_dep
# 6                     LGBMRegressor(n_estimators=200)  ln_ged_sb_dep
# 7   HurdleRegression(clf_name='LGBMClassifier', cl...  ln_ged_sb_dep
# 8                     LGBMRegressor(n_estimators=200)  ln_ged_sb_dep
# 9   XGBRegressor(base_score=None, booster=None, co...  ln_ged_sb_dep
# 10  HurdleRegression(clf_name='XGBClassifier',\n  ...  ln_ged_sb_dep
# 11  HurdleRegression(clf_name='XGBClassifier',\n  ...  ln_ged_sb_dep
#
#                                           queryset        data_train  \
# 0                              hh_fat_pgm_baseline          baseline
# 1                          hh_fat_pgm_conflictlong      conflictlong
# 2                          hh_fat_pgm_conflictlong      conflictlong
# 3              fat_escwa_drought_vulnerability_pgm     escwa_drought
# 4              fat_escwa_drought_vulnerability_pgm     escwa_drought
# 5                                hh_fat_pgm_natsoc            natsoc
# 6                                hh_fat_pgm_natsoc            natsoc
# 7                                 hh_fat_pgm_broad             broad
# 8                                 hh_fat_pgm_broad             broad
# 9                paola_fatalities_conflict_history   paola_conf_hist
# 10                jim_pgm_conflict_treelag_d_1_d_2      conf_treelag
# 11  jim_pgm_conflict_target_sptime_dist_nu1_10_001  conf_sptime_dist
#
#                                        Algorithm_text  \
# 0                     LGBMRegressor(n_estimators=200)
# 1                     LGBMRegressor(n_estimators=200)
# 2   HurdleRegression(clf_name='LGBMClassifier', cl...
# 3   HurdleRegression(clf_name='LGBMClassifier', cl...
# 4                     LGBMRegressor(n_estimators=200)
# 5   HurdleRegression(clf_name='LGBMClassifier', cl...
# 6                     LGBMRegressor(n_estimators=200)
# 7   HurdleRegression(clf_name='LGBMClassifier', cl...
# 8                     LGBMRegressor(n_estimators=200)
# 9   XGBRegressor(base_score=None, booster=None, co...
# 10  HurdleRegression(clf_name='XGBClassifier',\n  ...
# 11  HurdleRegression(clf_name='XGBClassifier',\n  ...
#
#                           RunResult_calib  \
# 0   RunResult(training_date = 2022-02-23)
# 1   RunResult(training_date = 2022-02-23)
# 2   RunResult(training_date = 2022-02-23)
# 3   RunResult(training_date = 2022-02-23)
# 4   RunResult(training_date = 2022-02-23)
# 5   RunResult(training_date = 2022-02-23)
# 6   RunResult(training_date = 2022-02-23)
# 7   RunResult(training_date = 2022-02-23)
# 8   RunResult(training_date = 2022-02-23)
# 9   RunResult(training_date = 2022-03-18)
# 10  RunResult(training_date = 2022-02-09)
# 11  RunResult(training_date = 2022-02-09)
#
#                                   predstore_calib  \
# 0              pgm_fat_jed_hh_baseline_lgbm_calib
# 1          pgm_fat_jed_hh_conflictlong_lgbm_calib
# 2   pgm_fat_jed_hh_conflictlong_hurdle_lgbm_calib
# 3        pgm_fat_jed_hh_drought_hurdle_lgbm_calib
# 4               pgm_fat_jed_hh_drought_lgbm_calib
# 5         pgm_fat_jed_hh_natsoc_hurdle_lgbm_calib
# 6                pgm_fat_jed_hh_natsoc_lgbm_calib
# 7          pgm_fat_jed_hh_broad_hurdle_lgbm_calib
# 8                 pgm_fat_jed_hh_broad_lgbm_calib
# 9              pgm_fat_jed_pv_conf_hist_pgm_calib
# 10         pgm_fat_tree_lags_d_1_d_2_hur_36_calib
# 11    pgm_fat_sptime_dist_nu1_10_001_hur_36_calib
#
#                            RunResult_test  \
# 0   RunResult(training_date = 2022-05-16)
# 1   RunResult(training_date = 2022-05-17)
# 2   RunResult(training_date = 2022-05-17)
# 3   RunResult(training_date = 2022-05-17)
# 4   RunResult(training_date = 2022-05-18)
# 5   RunResult(training_date = 2022-05-18)
# 6   RunResult(training_date = 2022-05-18)
# 7   RunResult(training_date = 2022-05-18)
# 8   RunResult(training_date = 2022-05-18)
# 9   RunResult(training_date = 2022-05-18)
# 10  RunResult(training_date = 2022-05-18)
# 11  RunResult(training_date = 2022-05-18)
#
#                                   predstore_test  \
# 0              pgm_fat_jed_hh_baseline_lgbm_test
# 1          pgm_fat_jed_hh_conflictlong_lgbm_test
# 2   pgm_fat_jed_hh_conflictlong_hurdle_lgbm_test
# 3        pgm_fat_jed_hh_drought_hurdle_lgbm_test
# 4               pgm_fat_jed_hh_drought_lgbm_test
# 5         pgm_fat_jed_hh_natsoc_hurdle_lgbm_test
# 6                pgm_fat_jed_hh_natsoc_lgbm_test
# 7          pgm_fat_jed_hh_broad_hurdle_lgbm_test
# 8                 pgm_fat_jed_hh_broad_lgbm_test
# 9              pgm_fat_jed_pv_conf_hist_pgm_test
# 10         pgm_fat_tree_lags_d_1_d_2_hur_36_test
# 11    pgm_fat_sptime_dist_nu1_10_001_hur_36_test
#
#                          RunResult_future  \
# 0   RunResult(training_date = 2022-02-23)
# 1   RunResult(training_date = 2022-02-23)
# 2   RunResult(training_date = 2022-02-23)
# 3   RunResult(training_date = 2022-02-23)
# 4   RunResult(training_date = 2022-02-23)
# 5   RunResult(training_date = 2022-02-23)
# 6   RunResult(training_date = 2022-02-23)
# 7   RunResult(training_date = 2022-02-23)
# 8   RunResult(training_date = 2022-02-23)
# 9   RunResult(training_date = 2022-03-18)
# 10  RunResult(training_date = 2022-02-23)
# 11  RunResult(training_date = 2022-02-23)
#
#                                 predstore_future
# 0              pgm_fat_jed_hh_baseline_lgbm_f506
# 1          pgm_fat_jed_hh_conflictlong_lgbm_f506
# 2   pgm_fat_jed_hh_conflictlong_hurdle_lgbm_f506
# 3        pgm_fat_jed_hh_drought_hurdle_lgbm_f506
# 4               pgm_fat_jed_hh_drought_lgbm_f506
# 5         pgm_fat_jed_hh_natsoc_hurdle_lgbm_f506
# 6                pgm_fat_jed_hh_natsoc_lgbm_f506
# 7          pgm_fat_jed_hh_broad_hurdle_lgbm_f506
# 8                 pgm_fat_jed_hh_broad_lgbm_f506
# 9              pgm_fat_jed_pv_conf_hist_pgm_f506
# 10         pgm_fat_tree_lags_d_1_d_2_hur_36_f506
# 11    pgm_fat_sptime_dist_nu1_10_001_hur_36_f506

# %%
ModelList_df = pd.DataFrame.from_dict(ModelList)
localpath = './'

filename = localpath + 'Model_pgm_' + model['modelname'] + '_'+ dev_id + '.csv'
ModelList_df.to_csv(filename)
gitname = 'ModelList_pgm_wide_' + dev_id + '.csv'
ModelList_df.to_csv(gitname)
